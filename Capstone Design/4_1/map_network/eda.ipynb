# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# 엑셀 파일 경로
file_path = 'data/link.xlsx'

# 엑셀 파일 읽기
df = pd.read_excel(file_path)

# DataFrame 출력
print(df)
# Out:
#         objectid      link_id sido_nm sgg_nm emd_nm  wroad_cate  link_cate  \
# 0              1  28300152678   인천광역시     서구   청라2동           3         12
# 1              2  28300394332   인천광역시    연수구   송도3동           3         12
# 2              3  28200036232   인천광역시    강화군    길상면           2          5
# 3              4  28200036270   인천광역시    강화군    길상면           2          5
# 4              5  28200036338   인천광역시    강화군    길상면           2          5
# ...          ...          ...     ...    ...    ...         ...        ...
# 424266    424267  28200426937   인천광역시     중구    운서동           2          9
# 424267    424268  28200426938   인천광역시     중구    운서동           2          9
# 424268    424269  28200426939   인천광역시     중구    운서동           2          9
# 424269    424270  28200426940   인천광역시     중구    운서동           2          9
# 424270    424271  28200426941   인천광역시     중구    운서동           2          9
#
# ...

# %%
df = pd.read_pickle('data/link.pkl')

df = df[df['emd_nm'].str.contains('송도1동')]

df
# Out:
#         objectid      link_id sido_nm sgg_nm emd_nm  wroad_cate  link_cate  \
# 321          322  28300000570   인천광역시    연수구   송도1동           3         23
# 322          323  28300000568   인천광역시    연수구   송도1동           3         23
# 356          357  28100066849   인천광역시    연수구   송도1동           1          4
# 761          762  28300426479   인천광역시    연수구   송도1동           3         23
# 763          764  28300426481   인천광역시    연수구   송도1동           3         23
# ...          ...          ...     ...    ...    ...         ...        ...
# 423683    423684  28200422075   인천광역시    연수구   송도1동           2          9
# 423684    423685  28200422081   인천광역시    연수구   송도1동           2          9
# 423685    423686  28200422080   인천광역시    연수구   송도1동           2          9
# 423686    423687  28200422079   인천광역시    연수구   송도1동           2          9
# 423707    423708  28200422363   인천광역시    연수구   송도1동           2          5
#
# ...

# %%
df.to_pickle('data/link_songdo1dong.pkl')
